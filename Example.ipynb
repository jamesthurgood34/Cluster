# %%
import Cluster as cl
import gensim

# %%
dir(cl)
# Out:
# ['Cluster',
#  'Documents',
#  'DocumentsWithDict',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  'gensim',
#  'logger',
#  'logging',
#  'nltk',
#  'string']

# %%
import nltk
emma = nltk.corpus.gutenberg.words('austen-emma.txt')

# %%
emma = {k : v for k, v in enumerate(nltk.corpus.gutenberg.raw().split('\n\n'))}

# %%
docs = cl.Documents(emma)
# Out:
# helloooo

# %%
docs.remove_punctuation()

# %%
docs.lower_case()

# %%
docs_with_dict = docs.create_dictionary()

# %%
docs_with_dict.remove_singleLettersAndNumbers()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-3e9a128ff702> in <module>
# ----> 1 docs_with_dict.remove_singleLettersAndNumbers()
#
# AttributeError: 'DocumentsWithDict' object has no attribute 'remove_singleLettersAndNumbers'

# %%
docs_with_dict.remove_stopwords()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-13-73a624fe98f8> in <module>
# ----> 1 docs_with_dict.remove_stopwords()
#
# ~/Documents/work/ClusteringCodeJT/Cluster/Cluster.py in remove_stopwords(self)
#      93
#      94     def remove_stopwords(self):
# ---> 95         self._remove_words(self.standard_stopwords)
#      96
#      97     def remove_custom_stopwords(self):
#
# ~/Documents/work/ClusteringCodeJT/Cluster/Cluster.py in _remove_words(self, words)
#      86     def _remove_words(self, words):
#      87         self.dict_id2word.filter_tokens(
# ---> 88                                     bad_ids=[self.dict_id2word.token2id[word] for word in words if word in self.vocab])
#      89
#      90     def remove_singleLettersAndNumbers(self):
#
# ~/Documents/work/ClusteringCodeJT/Cluster/Cluster.py in <listcomp>(.0)
#      86     def _remove_words(self, words):
#      87         self.dict_id2word.filter_tokens(
# ---> 88                                     bad_ids=[self.dict_id2word.token2id[word] for word in words if word in self.vocab])
#      89
#      90     def remove_singleLettersAndNumbers(self):
#
# KeyError: 'a'

# %%
# Out:
# dict_keys(['austen', 'by', 'emma', 'jane', 'volume', 'chapter', 'and', 'best', 'blessings', 'clever', 'comfortable', 'disposition', 'distress', 'existence', 'had', 'handsome', 'happy', 'her', 'home', 'in', 'little', 'lived', 'nearly', 'of', 'one', 'or', 'rich', 'seemed', 'some', 'the', 'to', 'twenty', 'unite', 'very', 'vex', 'with', 'woodhouse', 'world', 'years', 'affection', 'affectionate', 'ago', 'an', 'as', 'been', 'caresses', 'consequence', 'daughters', 'died', 'early', 'excellent', 'fallen', 'father', 'for', 'from', 'governess', 'have', 'his', 'house', 'indistinct', 'indulgent', 'long', 'marriage', 'mistress', 'more', 'most', 'mother', 'period', 'place', 'remembrance', 'she', 'short', 'sister', 'supplied', 'than', 'too', 'two', 'was', 'who', 'woman', 'youngest', 'allowed', 'any', 'attached', 'authority', 'away', 'before', 'being', 'between', 'both', 'but', 'ceased', 'chiefly', 'directed', 'doing', 'esteeming', 'even', 'family', 'fond', 'friend', 'hardly', 'highly', 'hold', 'impose', 'intimacy', 'it', 'judgment', 'just', 'less', 'liked', 'living', 'mildness', 'miss', 'mr', 'mutually', 'nominal', 'now', 'office', 'own', 'particularly', 'passed', 'restraint', 'shadow', 'sisters', 'sixteen', 'taylor', 'temper', 'them', 'they', 'together', 'what', 'alloy', 'at', 'danger', 'did', 'disadvantages', 'enjoyments', 'evils', 'having', 'herself', 'however', 'indeed', 'many', 'means', 'misfortunes', 'much', 'not', 'power', 'present', 'rank', 'rather', 'real', 'situation', 'so', 'that', 'these', 'think', 'threatened', 'unperceived', 'way', 'well', 'were', 'which', 'after', 'all', 'beloved', 'bride', 'brought', 'came', 'cheer', 'composed', 'consciousness', 'continuance', 'day', 'dine', 'dinner', 'disagreeable', 'evening', 'first', 'gentle', 'gone', 'grief', 'himself', 'left', 'loss', 'lost', 'married', 'mournful', 'no', 'on', 'only', 'over', 'people', 'prospect', 'sat', 'shape', 'sit', 'sleep', 'sorrow', 'then', 'third', 'this', 'thought', 'usual', 'wedding', 'age', 'always', 'amuse', 'arose', 'attach', 'be', 'black', 'character', 'childhood', 'companion', 'concerns', 'considering', 'could', 'dearer', 'debt', 'denying', 'devoted', 'each', 'easy', 'equal', 'event', 'every', 'fault', 'felt', 'few', 'find', 'five', 'followed', 'footing', 'fortune', 'friendship', 'generous', 'gratitude', 'happiness', 'health', 'here', 'hers', 'hour', 'how', 'illnesses', 'informed', 'intelligent', 'intercourse', 'interested', 'isabella', 'its', 'kindness', 'knowing', 'large', 'last', 'man', 'manners', 'match', 'morning', 'never', 'nursed', 'old', 'other', 'owing', 'past', 'peculiarly', 'perfect', 'played', 'pleasant', 'pleasure', 'possessed', 'powers', 'promise', 'promoted', 'recalled', 'recollection', 'satisfaction', 'scheme', 'self', 'seven', 'soon', 'speak', 'such', 'suitable', 'taught', 'tenderer', 'their', 'there', 'through', 'unexceptionable', 'unreserve', 'useful', 'various', 'want', 'ways', 'weston', 'whom', 'wished', 'work', 'would', 'yet', 'advantages', 'aware', 'bear', 'change', 'conversation', 'dearly', 'difference', 'domestic', 'going', 'great', 'half', 'he', 'intellectual', 'loved', 'meet', 'mile', 'mrs', 'must', 'natural', 'playful', 'rational', 'solitude', 'suffering', 'true', 'activity', 'actual', 'ages', 'amiable', 'body', 'constitution', 'disparity', 'everywhere', 'evil', 'friendliness', 'habits', 'heart', 'him', 'increased', 'life', 'mind', 'older', 'recommended', 'talents', 'though', 'time', 'valetudinarian', 'without', 'again', 'beyond', 'children', 'christmas', 'comparatively', 'daily', 'fill', 'give', 'hartfield', 'husband', 'london', 'matrimony', 'miles', 'next', 'november', 'october', 'off', 'reach', 'removed', 'settled', 'society', 'struggled', 'visit', 'able', 'accepted', 'acquaintance', 'afforded', 'almost', 'among', 'amounting', 'awoke', 'belong', 'chatted', 'cheerful', 'cheerfully', 'civil', 'compassion', 'daughter', 'deal', 'depressed', 'differently', 'disposed', 'done', 'easily', 'entirely', 'equals', 'ever', 'exactly', 'feel' ...
